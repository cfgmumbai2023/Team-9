# %%
import pandas as pd

# %%
df = pd.read_csv('data_adarsh.csv')

# %%
x = df['DISABILITY'].value_counts().head()

# %%
df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>BMC SCHOOL</th>\n      <th>AGE</th>\n      <th>DISABILITY</th>\n      <th>severity</th>\n      <th>program</th>\n      <th>level</th>\n      <th>gender</th>\n      <th>two words</th>\n      <th>VOCABULARY BUILDING</th>\n      <th>TRADITIONAL AND MODERN GAME</th>\n      <th>MUMBAI MAP TOPOGRAFY</th>\n      <th>LEMON SRBAT MAKING</th>\n      <th>STAMPING THE DESING</th>\n      <th>ADDITION ,SUBTRACTION</th>\n      <th>FRACTION</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>R.N. Podar School</td>\n      <td>9</td>\n      <td>Visual impairment</td>\n      <td>high</td>\n      <td>Smriti Program</td>\n      <td>1</td>\n      <td>Female</td>\n      <td>No word</td>\n      <td>7</td>\n      <td>6</td>\n      <td>9</td>\n      <td>8</td>\n      <td>5</td>\n      <td>9</td>\n      <td>4</td>\n    </tr>\n  
# ...

# %%
df
# Out:
#      Unnamed: 0                              BMC SCHOOL  AGE  \
# 0             0                       R.N. Podar School    9
# 1             1                     Pawar Public School   11
# 2             2        Dr. Antonio Da Silva High School    7
# 3             3        Dr. Antonio Da Silva High School    6
# 4             4                       R.N. Podar School    8
# ..          ...                                     ...  ...
# 495         495  Dr. Sarvepalli Radhakrishnan Vidyalaya   12
# 496         496                      HVB Global Academy    5
# 497         497                     Pawar Public School   15
# 498         498                        Vissanji Academy    4
# 499         499                       R.N. Podar School    6
#
#                    DISABILITY severity            program  level  gender  \
# 0           Visual impairment     high     Smriti Program      1  Female
# 1        Cognitive impairment     high     Smriti Program      3    Male
# ...
